# %%
import lasio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
log = lasio.read('../volve_well_logs/Well_logs/06.LFP/15_9-19 BT2/159-19BT2_LFP.las')
# Out:
# Header section Parameter regexp=~P was not found.

# %%
for curve in log.curves:
    print(curve.mnemonic)  # print out the curve mnemonics
# Out:
# DEPTH
# LFP_AI
# LFP_AI_B
# LFP_AI_G
# LFP_AI_LOG
# LFP_AI_O
# LFP_AI_V
# LFP_API
# LFP_BADDATA
# LFP_BVWE
# LFP_BVWT
# LFP_COAL
# LFP_DT
# LFP_DT_B
# LFP_DT_G
# LFP_DT_LOG
# LFP_DT_O
# LFP_DT_SYNT
# LFP_DT_V
# LFP_DTCORFSFLAG
# LFP_DTS
# LFP_DTS_B
# LFP_DTS_G
# LFP_DTS_GC
# LFP_DTS_LOG
# LFP_DTS_O
# LFP_DTS_V
# LFP_EI_HILT_B
# LFP_EI_HILT_G
# LFP_EI_HILT_O
# LFP_EI_HILT_V
# LFP_GAS
# LFP_GOR
# LFP_GR
# LFP_GRMAX
# LFP_GRMIN
# LFP_KFLG
# LFP_KFLMF
# LFP_KFLO
# LFP_KFLW
# LFP_KROCKV
# LFP_KRROCKV
# LFP_KSKEL
# LFP_KVROCKV
# LFP_MODEL
# LFP_NPHI
# LFP_NPHISH
# LFP_OIL
# LFP_PHIE
# LFP_PHIEC
# LFP_PHIEWC
# LFP_PHIT
# LFP_PHITC
# LFP_PHITWC
# LFP_PR
# LFP_PR_B
# LFP_PR_G
# LFP_PR_LOG
# LFP_PR_O
# LFP_PR_SH_SYNT
# LFP_PR_SS_B_SYNT
# LFP_PR_SS_G_SYNT
# LFP_PR_SS_O_SYNT
# LFP_PR_V
# LFP_PRESS
# LFP_RHOB
# LFP_RHOB_B
# LFP_RHOB_G
# LFP_RHOB_LOG
# LFP_RHOB_O
# LFP_RHOB_SYNT
# LFP_RHOB_V
# LFP_RHOBFAR_HILT_B
# LFP_RHOBFAR_HILT_G
# LFP_RHOBFAR_HILT_O
# LFP_RHOBFAR_HILT_V
# LFP_RHOBLOGFLAG
# LFP_RHOBSH
# LFP_RHOBSHNC
# LFP_RHOFLE
# LFP_RHOFLEC
# LFP_RHOFLEWC
# LFP_RHOFLT
# LFP_RHOFLTC
# LFP_RHOFLTWC
# LFP_RHOG
# LFP_RHOHA
# LFP_RHOHW
# LFP_RHOMA
# LFP_RHOMANC
# LFP_RHOMF
# LFP_RHOO
# LFP_RHOW
# LFP_RSH
# LFP_RT
# LFP_RW
# LFP_SAL
# LFP_SAND
# LFP_SANDC
# LFP_SANDWC
# LFP_SGG_G
# LFP_SGG_O
# LFP_SGT
# LFP_SGT_SUBST
# LFP_SI
# LFP_SI_LOG
# LFP_SOT
# LFP_SOT_SUBST
# LFP_SUBST
# LFP_SWE
# LFP_SWEC
# LFP_SWECNC
# LFP_SWT
# LFP_SWTC
# LFP_SWTCNC
# LFP_SXOGT
# LFP_SXOMFE
# LFP_SXOMFEC
# LFP_SXOMFEWC
# LFP_SXOMFT
# LFP_SXOMFTC
# LFP_SXOMFTWC
# LFP_SXOMIXE
# LFP_SXOMIXEC
# LFP_SXOMIXT
# LFP_SXOMIXTC
# LFP_SXOOT
# LFP_SXOWE
# LFP_SXOWEC
# LFP_SXOWEWC
# LFP_SXOWT
# LFP_SXOWTC
# LFP_SXOWTWC
# LFP_TEMP
# LFP_TVD
# LFP_TVDML
# LFP_TVDSS
# LFP_VCARB
# LFP_VCARBC
# LFP_VCARBWC
# LFP_VP
# LFP_VP_B
# LFP_VP_G
# LFP_VP_LOG
# LFP_VP_O
# LFP_VP_V
# LFP_VPG
# LFP_VPO
# LFP_VPVS
# LFP_VPVS_B
# LFP_VPVS_G
# LFP_VPVS_LOG
# LFP_VPVS_O
# LFP_VPVS_V
# LFP_VPW
# LFP_VQRTZ
# LFP_VQRTZC
# LFP_VQRTZWC
# LFP_VS
# LFP_VS_B
# LFP_VS_G
# LFP_VS_GC
# LFP_VS_LOG
# LFP_VS_O
# LFP_VS_V
# LFP_VSH
# LFP_VSHDN
# LFP_VSHDRY
# LFP_VSHDRYC
# LFP_VSHDRYWC
# LFP_VSHGR
# LFP_WATER

# %%
lwd = log.df()  # creates a dataframe from the lasio object
lwd["measured depth"] = lwd.index  # let's add the depth track as a series
lwd.head()  # check out the DataFrame
# Out:
#               LFP_AI   LFP_AI_B   LFP_AI_G  LFP_AI_LOG   LFP_AI_O   LFP_AI_V  \
# DEPTH
# 3170.0725  6842.3330  6842.3330  6842.3330   6515.8818  6842.3330  6842.3330
# 3170.2249  7511.2642  7511.2642  7511.2642   7161.6558  7511.2642  7511.2642
# 3170.3772  7527.4360  7527.4360  6623.8350   6767.1621  7102.3110  7527.4360
# 3170.5298  7696.3848  7696.3848  6862.2749   7007.9248  7312.8330  7696.3848
# 3170.6821  7452.2202  7452.2202  6497.6152   6977.9150  6944.0791  7452.2202
#
#            LFP_API  LFP_BADDATA  LFP_BVWE  LFP_BVWT       ...        LFP_VS_O  \
# DEPTH                                                     ...
# 3170.0725   1.0687          1.0    0.0988    0.2366       ...        1571.599
# 3170.2249   1.0687          1.0    0.0355    0.1875       ...        1569.115
# 3170.3772   1.0687          1.0    0.1130    0.2302       ...        1611.313
# 3170.5298   1.0687          1.0    0.1018    0.2197       ...        1620.012
# 3170.6821   1.0687          1.0    0.1692    0.2459       ...        1631.788
#
#            LFP_VS_V  LFP_VSH  LFP_VSHDN  LFP_VSHDRY  LFP_VSHDRYC  \
# DEPTH
# 3170.0725  1571.599   0.4500        NaN      0.3123       0.3123
# 3170.2249  1569.115   0.5905        NaN      0.4384       0.4384
# 3170.3772  1600.050   0.3099        NaN      0.1927       0.1927
# 3170.5298  1609.892   0.3355        NaN      0.2176       0.2176
# 3170.6821  1614.495   0.2271        NaN      0.1503       0.1503
#
#            LFP_VSHDRYWC  LFP_VSHGR  LFP_WATER  measured depth
# DEPTH
# 3170.0725        0.3123     0.4500        1.0       3170.0725
# 3170.2249        0.4384     0.5905        1.0       3170.2249
# 3170.3772        0.1927     0.3099        1.0       3170.3772
# 3170.5298        0.2176     0.3355        1.0       3170.5298
# 3170.6821        0.1503     0.2271        1.0       3170.6821
#
# [5 rows x 172 columns]

# %%
lwd.columns
# Out:
# Index(['LFP_AI', 'LFP_AI_B', 'LFP_AI_G', 'LFP_AI_LOG', 'LFP_AI_O', 'LFP_AI_V',
#        'LFP_API', 'LFP_BADDATA', 'LFP_BVWE', 'LFP_BVWT',
#        ...
#        'LFP_VS_O', 'LFP_VS_V', 'LFP_VSH', 'LFP_VSHDN', 'LFP_VSHDRY',
#        'LFP_VSHDRYC', 'LFP_VSHDRYWC', 'LFP_VSHGR', 'LFP_WATER',
#        'measured depth'],
#       dtype='object', length=172)

# %%
from io import StringIO

with open('../Volve_Well_technical_data/Well_technical_data/WellWellbore/15_9-19/15_9-19 BT2/Volve F_159-19_19 BT2_19 BT2_ACTUAL') as f:
    data = f.read()
    columns = data.split('SURVEY LIST')[1]

csvcols = StringIO(columns)

df = pd.read_csv(csvcols, delim_whitespace=True, header=1)

df.head()
# Out:
#         m   RKB     deg   deg.1    m.1  RKB.1         m.2          m.3   m.4  \
# 0  109.00  0.00    0.00  109.00  7.024  6.886  435057.043  6478570.406  0.00
# 1  122.95  0.07  171.75  122.96  6.994  6.836  435057.013  6478570.356  0.15
# 2  133.00  0.08  251.31  132.98  6.994  6.816  435057.013  6478570.336  0.29
# 3  142.96  0.08  250.95  142.96  7.014  6.806  435057.033  6478570.326  0.00
# 4  152.93  0.09  231.63  152.91  7.034  6.786  435057.053  6478570.306  0.09
#
#    m.5  deg/30m
# 0  NaN      NaN
# 1  NaN      NaN
# 2  NaN      NaN
# 3  NaN      NaN
# 4  NaN      NaN

# %%
#%matplotlib qt

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

X = df['m.1']
Y = df['RKB.1']
Z = df['m']

max_range = np.array([X.max()-X.min(), Y.max()-Y.min(), Z.max()-Z.min()]).max() / 2.0

mid_x = (X.max()+X.min()) * 0.5
mid_y = (Y.max()+Y.min()) * 0.5
mid_z = (Z.max()+Z.min()) * 0.5
ax.set_xlim(mid_x - max_range, mid_x + max_range)
ax.set_ylim(mid_y - max_range, mid_y + max_range)
ax.set_zlim(mid_z - max_range, mid_z + max_range)

ax.scatter(X, Y, Z)
ax.invert_zaxis()
